# %% [markdown]
# # Customer Journey Visualization

# %% [markdown]
# ### Importing Data

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

customer_journey = pd.read_csv('../data/processed/customer_journey.csv')

# %% [markdown]
# ### 1.Channel Performance

# %%
channel_conversion = customer_journey.groupby('Country')['CustomerID'].count().sort_values(ascending=False).head(5)

figure = go.Figure(
  go.Bar(
    x=channel_conversion.index,
    y=channel_conversion.values,
    text=(channel_conversion.values),
    textposition='auto',
    name='Channel Conversion Rate'
  )
)

figure.show()

# %% [markdown]
# ### 2.Conversion Funnel

# %%
funnel_periods = ['Night', 'Morning', 'Afternoon', 'Evening']
funnel_values = [
  customer_journey[customer_journey['TimeOfDay'] == period].groupby('TimeOfDay')['CustomerID'].count().values[0]
  for period in funnel_periods
]
funnel_values.sort()

figure = go.Figure(
  px.funnel_area(
    names=funnel_periods,
    values=funnel_values
  )
)

figure.show()

# %%
customer_journey.head()
# Out:
#    InvoiceNo StockCode                        Description  Quantity  \
# 0     541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 1     537626     85116    BLACK CANDELABRA T-LIGHT HOLDER        12
# 2     537626     22375  AIRLINE BAG VINTAGE JET SET BROWN         4
# 3     537626     71477  COLOUR GLASS. STAR T-LIGHT HOLDER        12
# 4     537626     22492            MINI PAINT SET VINTAGE         36
#
#            InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount  \
# 0  2011-01-18 10:01:00       1.04     12346.0  United Kingdom      77183.6
# 1  2010-12-07 14:57:00       2.10     12347.0         Iceland         25.2
# 2  2010-12-07 14:57:00       4.25     12347.0         Iceland         17.0
# 3  2010-12-07 14:57:00       3.25     12347.0         Iceland         39.0
# 4  2010-12-07 14:57:00       0.65     12347.0         Iceland         23.4
#
#    Year  Month  DayOfWeek  HourOfDay  TimeOfDay  purchase_number  \
# ...

# %% [markdown]
# ### 3.Channel Performace Per Funnel
